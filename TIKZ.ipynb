# %%
# %load_ext tikzmagic

# %%
# %%tikz -l shapes.geometric,arrows,patterns --scale 1 --size 800,400 -f png
# \tikzstyle{Header} = [align=center,rectangle, rounded corners, minimum width=3cm, minimum height=2cm,text centered, draw=black, fill=red!30]
# %\draw[->,red] (0,0) -- (1,1);
# %\draw[->,blue,thick] (3,0) arc (0:90:0.51cm);
#
# \node (clienth) [Header] at (1cm,3cm) {Client HTML5};
# \node (client)[draw=black,fill=gray,minimum height=4cm, minimum width=3cm, align=center] at (1,0) {texte le\c con\\widget exo\\...\\texte le\c con\\widget exo\\...};
#
# \node (nbh) [Header, minimum width=4cm] at (7,3) {Student Personal Logic\\Python kernels derri\` ere\\Jupyter(Hub)};
# \node (nb) [draw=black,fill=gray,minimum height=4cm, minimum width=4cm, align=center] at (7,0) {Comm stub\\ \\Python snippets\\interprets the view \\ specification for \\ rendering};
# \draw[<->,red,thick] (client) -- (nb) node[midway,above]{WebSocket};
#
# \node (exoserverh) [Header, minimum width=4cm] at (14, 3) {Exo Server};
# \node (exoserver) [draw=black,fill=gray,minimum height=4cm, minimum width=4cm, align=center] at (14,0) {Build excercise\\logic and \\view specification\\given\\(exomid,userid)\\ \\Receive and validate\\answers};
#
# \node (exodb) [Header, fill=white, pattern=north west lines, pattern color=red!30] at (20,3) {Exo DB};
# \node (pedagdb) [Header, fill=white, pattern=north west lines, pattern color=red!30] at (20,0) {Pedag DB};
#
# \draw[<->,red,thick] (nb) -- (exoserver) node[midway,above]{HTTP};
# \draw[<->,red,dashed,thick] (exoserver) -- (exodb) node[midway,above,sloped]{get exo model};
# \draw[<->,red,dashed,thick] (exoserver) -- (pedagdb) node[midway,above,sloped]{get student} node[midway,below,sloped]{level};
# \node[draw, fill=blue, thick, minimum size=2cm] at (1cm,1cm) {FOO};

# %%
# %%tikz -l shapes.geometric,arrows,patterns --scale 1 --size 800,400 -f png
# \tikzstyle{ExoRepository} = [minimum width=2cm, font=\small]
# \node[coordinate] (a) at (0cm,0cm) {};
# \node[coordinate] (b) at (1cm,4cm) {};
# \node (c) [ExoRepository,draw] at (4cm,4cm){Exo Repository};
# \draw[-] (a) -- (b);

# %%
# %%tikz --size 800,400 -f png
#
# \coordinate (clientLineTop) at (1,5);
# \coordinate (clientLineBottom) at (1,-3);
#
# \coordinate (serverLineTop) at (10,5);
# \coordinate (serverLineBottom) at (10,-3);
#
# \draw [<-](clientLineBottom)--(clientLineTop) node[above]{Client};
# \draw [<-](serverLineBottom)--(serverLineTop) node[above]{Exo server};
#
# \coordinate (clientEmit1) at (1,4);
# \coordinate (serverReceive1) at (10,4);
#
# \coordinate (serverEmit2) at (10,2);
# \coordinate (clientReceive2) at (1,2);
#
# \coordinate (clientEmit3) at (1, 0);
# \coordinate (serverReceive3) at (10,0);
#
# \coordinate (serverEmit4) at (10,-2);
# \coordinate (clientReceive4) at (1, -2);
#
# \draw (clientEmit1) node{$\bullet$} node[left]{(A): Student query for new exercise};
# \draw (serverReceive1) node{$\bullet$} node[above right]{};
# \draw [->,dotted](clientEmit1)--(serverReceive1) node[left]{$>$} node[midway,above]{(B):(reqid0, userid, exospotid)};
# \draw (serverReceive1) arc (90:-90:1) [solid,->] node[midway,right]{(C):compute an instance of an exercise and a view} node{$<$};
# \draw [dotted] (serverEmit2)--(clientReceive2) node[midway,below]{(D):(reqid0,exoiid,exoInstanceDoc)} node[right]{$<$};
#
# \draw (clientEmit3) node{$\bullet$} node[left]{(E): Student proposes an answer};
# \draw [dotted] (clientEmit3)--(serverReceive3) node[midway,above]{(F):(reqid1,exoiid, answer)}node[left]{$>$} node{$\bullet$};
# \draw (serverReceive3) arc (90:-90:1) [solid,->] node[midway,right]{(G):check the answer} node{$<$};
#
# \draw [dotted] (serverEmit4) -- (clientReceive4) node[midway,below]{(H):(reqid1, verdict)}node[right]{$<$};

# %%
# %%tikz --size 1200,800 -f png
# \tikzstyle{DB} = [draw,rounded corners,fill=red!30,minimum height=1cm]
# \coordinate (serverLineTop) at (5,1);
# \coordinate (serverLineBottom) at (5,-15);
#
# \coordinate (samplerLineTop) at (10,-1);
# \coordinate (samplerLineBottom) at (10,-4);
# \draw (samplerLineTop) node[above,align=center]{Exo\\Sample Strategy} -- (samplerLineBottom);
#
# \coordinate (instanceFactoryTop) at ([xshift=2cm,yshift=-1cm]samplerLineBottom);
# \coordinate (instanceFactoryBottom) at ([yshift=-2cm]instanceFactoryTop);
# \draw (instanceFactoryTop) node[above]{Instance Factory}--(instanceFactoryBottom);
#
# \coordinate (viewFactoryTop) at ([yshift=-1cm]instanceFactoryBottom);
# \coordinate (viewFactoryBottom) at ([yshift=-2cm]viewFactoryTop);
# \draw (viewFactoryTop)node[above]{View Factory} --(viewFactoryBottom);
#
# \coordinate (recordProcessTop) at ([yshift=-1cm,xshift=1cm]viewFactoryBottom);
# \coordinate (recordProcessBottom) at ([yshift=-2cm]recordProcessTop);
# \draw (recordProcessTop) -- (recordProcessBottom);
# \node[DB] at ([xshift=2cm,yshift=-0.5cm]recordProcessTop) {Users Activity Tracker};
# \node[DB] at ([xshift=2cm,yshift=-1.5cm]recordProcessTop) {Exo Usage Tracker};
#
# \coordinate (clientEmit1) at (0,0);
# \coordinate (serverReceive1) at (5,0);
#
# \coordinate (serverEmit2) at (5,-0.5);
# \coordinate (serverReceive2) at (5,-1);
#
# \coordinate (serverEmit3) at (5,-1.5);
# \coordinate (samplerReceive3) at ([yshift=-1cm]samplerLineTop);
#
# \coordinate (samplerEmit4) at ([yshift=-0.5cm]samplerReceive3);
# \coordinate (dbreceive4) at (15,0);
#
# \coordinate (samplerEmit5) at ([yshift=-0.5cm]samplerEmit4);
# \coordinate (serverReceive5) at ([yshift=-2cm]serverEmit3);
#
# \coordinate (serverEmit6) at ([yshift=-2cm]serverReceive5);
# \coordinate (IFReceive6) at ([yshift=-0.5cm]instanceFactoryTop);
#
# \coordinate (IFEmit7) at ([yshift=-1cm]IFReceive6);
# \coordinate (serverReceive7) at ([yshift=-1cm]serverEmit6);
#
# \coordinate (serverEmit8) at ([yshift=-2cm]serverReceive7);
# \coordinate (VFReceive8) at ([yshift=-0.5cm]viewFactoryTop);
#
# \coordinate (VFEmit9) at ([yshift=-1cm]VFReceive8);
# \coordinate (serverReceive9) at ([yshift=-1cm]serverEmit8);
#
# \coordinate (serverEmit10) at ([yshift=-2cm]serverReceive9);
# \coordinate (recordProcessReceive10) at ([yshift=-0.5cm]recordProcessTop);
#
# \coordinate (recordProcessEmit11) at ([yshift=-1cm]recordProcessReceive10);
# \coordinate (serverReceive11) at ([yshift=-1cm]serverEmit10);
#
# \coordinate (serverEmit12) at ([yshift=-2cm]serverReceive11);
# \coordinate (clientReceive12) at (0,-14.5);
#
# \draw (clientEmit1) node {$\bullet$};
# \draw (serverReceive1) node {$\bullet$};
# \draw (serverLineTop) node[above]{ExoServer} --(serverLineBottom);
# \draw [->,dotted](clientEmit1)--(serverReceive1) node[left]{$>$} node[midway,above]{(reqid0, userid, exospotid)};
#
# \node[DB] at (15,2.5) {Learners Profiles};
# \node[DB] at (15,1.5) {Users Activity Tracker};
# \node[DB] at (15,0.5) {Exo Usage Tracker};
#
# \coordinate (exospotdb) at (10,2);
# \draw[->,dotted] (serverEmit2) node {$\bullet$} -- (exospotdb) node[midway,above,sloped]{exospotid} node[DB,above,solid] {\{exospotid $\Rightarrow$ [exomid, [viewid]]\}};
# \draw[->,dotted] (exospotdb) -- (serverReceive2) node[midway,below,sloped]{[exomid,[viewid]]=T};
#
# \draw[->,dotted] (serverEmit3) -- (samplerReceive3) node[midway,above,sloped]{(exospotid,userid,T)};
# \draw[<->,dotted] (samplerEmit4) -- (dbreceive4);
#
# \draw[->,dotted] (samplerEmit5) -- (serverReceive5) node[midway,above,sloped]{(exomid,viewid)};
#
# \draw[->,dotted] (serverEmit6)--(IFReceive6) node[midway,above]{exomid};
# \draw[<->,dotted] ([yshift=-0.5cm]IFReceive6)--([yshift=-0.5cm,xshift=3cm]IFReceive6) node[midway,above]{exomid} node[midway,below]{exo model} node[DB,right]{Exo Models Data Base};
# \draw[->,dotted] (IFEmit7) -- (serverReceive7) node[midway,above]{instance};
#
# \draw[->,dotted](serverEmit8)--(VFReceive8) node[midway,above]{instance,viewid};
# \draw[->,dotted](VFEmit9)--(serverReceive9) node[midway,above]{exo document};
#
# \draw[->,dotted](serverEmit10)--(recordProcessReceive10)node[midway,above,sloped]{(userid,exospotid,instance,reqid0)};
# \draw[->,dotted](recordProcessEmit11)--(serverReceive11)node[midway,below]{exoiid};
#
# \draw[->,dotted](serverEmit12)--(clientReceive12) node{$\bullet$} node[right]{$<$} node[midway,above]{(reqid0,exoiid,exo document)};
